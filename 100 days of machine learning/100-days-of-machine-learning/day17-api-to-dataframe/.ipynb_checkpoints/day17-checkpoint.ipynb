# %%
import pandas as pd
import requests

# Initialize an empty list to store DataFrames
dfs = []

for i in range(1, 429):
    try:
        response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
        response.raise_for_status()  # Check for errors in the HTTP response
        temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
        dfs.append(temp_df)
    except requests.exceptions.RequestException as e:
        print(f"Error in request {i}: {e}")

# Use the concat function to concatenate the list of DataFrames into a single DataFrame
df = pd.concat(dfs, ignore_index=True)

# Now df contains the data retrieved from the API

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  201088                  Blackhat
# 8556  615177           Coffee & Kareem
# 8557   97434                    Gambit
# 8558   23023               Tooth Fairy
# 8559  717728  Jeepers Creepers: Reborn
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  Nicholas Hathaway, a furloughed convict, and h...   2015-01-13
# 8556  A Detroit cop reluctantly teams with his girlf...   2020-04-03
# 8557  An art curator decides to seek revenge on his ...   2012-04-25
# 8558  When minor-league hockey player Derek Thompson...   2010-01-14
# 8559  Forced to travel with her boyfriend to a horro...   2022-09-15
#
#       popularity  vote_average  vote_count
# 0        121.693         8.704       25718
# 1        102.514         8.695       19543
# 2         68.971         8.577       11803
# 3         57.702         8.565       15182
# 4         45.314         8.539        8096
# ...          ...           ...         ...
# 8555      32.678         5.479        1939
# 8556      10.021         5.478         391
# 8557      11.447         5.478         636
# 8558      21.390         5.478        1893
# 8559      47.141         5.477         926
#
# [8560 rows x 7 columns]

# %%
df.to_csv('movies.csv')
